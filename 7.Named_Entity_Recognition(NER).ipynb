# %%
import nltk 
from nltk import word_tokenize, pos_tag,ne_chunk
from nltk.tree import Tree

# %%
# Download required packages (run once)
nltk.download('punkt')
nltk.download('averanged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tamil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading averanged_perceptron_tagger: Package
# [nltk_data]     'averanged_perceptron_tagger' not found in index
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\tamil\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\tamil\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
#Sample Text
text = "Marvel Comics was founded by Martin Goodman in New York City in 1939."

# %%
#Tokenization
tokens = word_tokenize(text)

# %%
#POS Tagging
pos_tags = pos_tag(tokens)

# %%
# NER
ner_tree = ne_chunk(pos_tags)

# %%
#Display Named Entities
print("Named Entities:\n")
for subtree in ner_tree:
    if isinstance (subtree, Tree):
        entity = " ".join([word for word, tag in subtree.leaves()])
        label = subtree.label()
        print(entity, "->", label)
# Out:
# Named Entities:
#
# Marvel -> PERSON
# Comics -> ORGANIZATION
# Martin Goodman -> PERSON
# New York City -> GPE
