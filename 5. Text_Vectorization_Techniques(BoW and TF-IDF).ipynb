# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#Sample corpus
corpus = [
    "Naatural Language Processing is fun"
    "Text preprocessing is an important NLP step"
]

#Bag of Words
bow = CountVectorizer()
bow_matrix = bow.fit_transform(corpus)
print("BoW Feature Names", bow.get_feature_names_out())
print("Bow Matrix:\n", bow_matrix.toarray())
# Out:
# BoW Feature Names ['an' 'funtext' 'important' 'is' 'language' 'naatural' 'nlp'
#  'preprocessing' 'processing' 'step']
# Bow Matrix:
#  [[1 1 1 2 1 1 1 1 1 1]]

# %%
# TF-IDF
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(corpus)
print("TF-IDF Feature Names:",tfidf.get_feature_names_out())
print("TF-IDF Matrix:\n",tfidf_matrix.toarray())
# Out:
# TF-IDF Feature Names: ['an' 'funtext' 'important' 'is' 'language' 'naatural' 'nlp'
#  'preprocessing' 'processing' 'step']
# TF-IDF Matrix:
#  [[0.2773501 0.2773501 0.2773501 0.5547002 0.2773501 0.2773501 0.2773501
#   0.2773501 0.2773501 0.2773501]]
